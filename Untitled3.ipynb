# %%
import pandas as pd
import os

# %%
csv_data = pd.read_csv('./web/assets/ks-projects-201801.csv', error_bad_lines=False)
df = pd.DataFrame(csv_data)
df.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
df['campaign_id'] = df['ID'].fillna(0)
del df['ID']
df['name'] = df['name'].fillna('unknown')
df['category'] = df['category'].fillna('unknown')
df['main_category'] = df['main_category'].fillna('unknown')
df['currency'] = df['currency'].fillna('unknown')
df['deadline'] = df['deadline'].fillna('1970-01-01')
df['goal'] = df['goal'].fillna(0.0)
df['launched'] = df['launched'].fillna('1970-01-01')
df['pledged'] = df['pledged'].fillna(0.0)
df['state'] = df['state'].fillna('unknown')
df['backers'] = df['backers'].fillna(0)
df['country'] = df['country'].fillna('unknown')
df['usd_pledged'] = df['usd pledged'].fillna(0.0)
del df['usd pledged']
df['usd_pledged_real'] = df['usd_pledged_real'].fillna(0.0)
df['usd_goal_real'] = df['usd_goal_real'].fillna(0.0)

# %%
df.head()
# Out:
#                                                 name        category  \
# 0                    The Songs of Adelaide & Abullah          Poetry
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 2                                     Where is Hank?  Narrative Film
# 3  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 4  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#   main_category currency    deadline     goal             launched  pledged  \
# 0    Publishing      GBP  2015-10-09   1000.0  2015-08-11 12:12:28      0.0
# 1  Film & Video      USD  2017-11-01  30000.0  2017-09-02 04:43:57   2421.0
# 2  Film & Video      USD  2013-02-26  45000.0  2013-01-12 00:20:50    220.0
# 3         Music      USD  2012-04-16   5000.0  2012-03-17 03:24:11      1.0
# 4  Film & Video      USD  2015-08-29  19500.0  2015-07-04 08:35:03   1283.0
#
#       state  backers country  usd_pledged_real  usd_goal_real  campaign_id  \
# ...

# %%
df = df.sort_values(by=['usd_pledged'], ascending=False)

# %%
df
# Out:
#                                                      name         category  \
# 157270   Pebble Time - Awesome Smartwatch, No Compromises   Product Design
# 250254  COOLEST COOLER: 21st Century Cooler that's Act...   Product Design
# 216629             Pebble 2, Time 2 + All-New Pebble Core   Product Design
# 282416       Pebble: E-Paper Watch for iPhone and Android   Product Design
# 293861  The World's Best TRAVEL JACKET with 15 Feature...   Product Design
# 187652                                  Exploding Kittens   Tabletop Games
# 6665               OUYA: A New Kind of Video Game Console  Gaming Hardware
# 368573                                          Shenmue 3      Video Games
# 30041      Pono Music - Where Your Soul Rediscovers Music            Sound
# 89481             Bring Back MYSTERY SCIENCE THEATER 3000       Television
# 148585                    The Veronica Mars Movie Project   Narrative Film
# ...
